# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
veriler=pd.read_json("veriler.json")
veriler
# Out:
#                             Unvan_İsim                              Birimi  \
# 0                Doç. Dr.  ERCAN BULUŞ         Çorlu Mühendislik Fakültesi
# 1                Doç. Dr.  ERDİNÇ UZUN         Çorlu Mühendislik Fakültesi
# 2          Dr. Öğr. Üyesi  ERKAN ÖZHAN         Çorlu Mühendislik Fakültesi
# 3        Dr. Öğr. Üyesi  AHMET SAYGILI         Çorlu Mühendislik Fakültesi
# 4   Öğr. Gör. Dr.  VİLDAN ATALAY AYDIN         Çorlu Mühendislik Fakültesi
# 5           Arş. Gör. Dr.  PINAR CİHAN         Çorlu Mühendislik Fakültesi
# 6            Öğr. Gör. Dr.  UFUK ÇETİN  Sosyal Bilimler Meslek Yüksekokulu
# 7            Prof. Dr.  BETÜL TAŞDELEN         Çorlu Mühendislik Fakültesi
# 8              Doç. Dr.  GÜL KAYKIOĞLU         Çorlu Mühendislik Fakültesi
# 9          Doç. Dr.  FATMA FÜSUN UYSAL         Çorlu Mühendislik Fakültesi
# 10      Dr. Öğr. Üyesi  AYLİN AKYILDIZ         Çorlu Mühendislik Fakültesi
# ...

# %%
veriler.plot.hist(alpha=0.7,stacked=True)
# Out:
# <img src="data:image/png;base64,..." width="575.5555708025713">
# <AxesSubplot:ylabel='Frequency'>

# %%
makale_say=pd.crosstab(veriler["Unvan_İsim"],veriler["Yayınlanan_Makale_Sayısı"])
makale_say
# Out:
# Yayınlanan_Makale_Sayısı            0    5    10   11   18   19   26   35   \
# Unvan_İsim
# Arş. Gör. Dr.  PINAR CİHAN            0    0    0    0    0    0    1    0
# Doç. Dr.  ERCAN BULUŞ                 0    0    0    0    0    0    0    0
# Doç. Dr.  ERDİNÇ UZUN                 0    0    0    0    0    0    0    0
# Doç. Dr.  FATMA FÜSUN UYSAL           0    0    0    0    0    0    0    0
# Doç. Dr.  GÜL KAYKIOĞLU               0    0    0    0    0    0    0    0
# Doç. Dr.  UĞUR AKYOL                  0    0    0    0    0    0    0    0
# Dr. Öğr. Üyesi  AHMET SAYGILI         0    0    0    0    0    0    0    0
# Dr. Öğr. Üyesi  AYDIN ÖZMUTLU         0    0    0    0    1    0    0    0
# Dr. Öğr. Üyesi  AYLİN AKYILDIZ        0    0    0    0    0    0    0    0
# Dr. Öğr. Üyesi  ERKAN ÖZHAN           0    0    0    0    0    0    0    0
# Dr. Öğr. Üyesi  NURŞEN ÖNTÜRK         0    0    0    0    1    0    0    0
# ...

# %%
makale_say.plot.bar()
# Out:
# <img src="data:image/png;base64,..." width="575.5555708025713">
# <AxesSubplot:xlabel='Unvan_İsim'>

# %%
fig=plt.figure()
x=veriler["Unvan_İsim"]
y=veriler["İdari_Görev_Sayısı"]
plt.plot(x,y)
plt.title("Akademisyenlerin yapmış oldukları İdari Görev Graiği")
plt.xlabel("Akademisyenlerin İsmi")
# Out:
# <img src="data:image/png;base64,..." width="575.5555708025713">
# Text(0.5, 0, 'Akademisyenlerin İsmi')

# %%
fig=plt.figure()
ax=plt.axes()
plt.plot(veriler.Unvan_İsim,veriler.Univeriste_Lİsans,"o")
# Out:
# <img src="data:image/png;base64,..." width="575.5555708025713">
